# %% [markdown]
# #The goal of this is to take an existing model and train it on some new data and add those labels to the classificiation
# #following this tutorial, https://codelabs.developers.google.com/codelabs/tensorflow-for-poets/#3

# %%
import tensorflow as tf
print (tf.VERSION)
# Out:
# 1.10.0

# %%
IMAGE_SIZE=224
ARCHITECTURE="mobilenet_0.50_%IMAGE_SIZE%"
ARCHITECTURE
"mobilenet_0.50_224"
# Out:
# 'mobilenet_0.50_%IMAGE_SIZE%'

# %%
#use mobile net
# %run scripts\retrain.py \
  --bottleneck_dir=tf_files/bottlenecks \
  --how_many_training_steps=20000 \
  --learning_rate=0.25 \
  --model_dir=tf_files/models/ \
  --summaries_dir=tf_files/training_summaries/"mobilenet_0.50_224" \
  --output_graph=tf_files/retrained_graph.pb \
  --output_labels=tf_files/retrained_labels.txt \
  --architecture="mobilenet_0.50_224" \
  --image_dir=tf_files/flower_photos
# Out:
# INFO:tensorflow:Looking for images in 'Apple___Apple_scab'
# INFO:tensorflow:Looking for images in 'Apple___Black_rot'
# INFO:tensorflow:Looking for images in 'Apple___Cedar_apple_rust'
# INFO:tensorflow:Looking for images in 'Apple___healthy'
# INFO:tensorflow:Looking for images in 'Blueberry___healthy'
# INFO:tensorflow:Looking for images in 'Cherry_(including_sour)___Powdery_mildew'
# INFO:tensorflow:Looking for images in 'Cherry_(including_sour)___healthy'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___Common_rust_'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___Northern_Leaf_Blight'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___healthy'
# INFO:tensorflow:Looking for images in 'Grape___Black_rot'
# INFO:tensorflow:Looking for images in 'Grape___Esca_(Black_Measles)'
# INFO:tensorflow:Looking for images in 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'
# ...

# %%
#use inception v3
# %run scripts\retrain.py \
  --bottleneck_dir=tf_files/bottlenecks \
  --how_many_training_step=20000 \
  --learning_rate=0.25 \
  --summaries_dir=training_summaries/LR_0.25 \
  --model_dir=tf_files/models/ \
  --output_graph=tf_files/retrained_graph.pb \
  --output_labels=tf_files/retrained_labels.txt \
  --image_dir=tf_files/flower_photos
# Out:
# INFO:tensorflow:Looking for images in 'Apple___Apple_scab'
# INFO:tensorflow:Looking for images in 'Apple___Black_rot'
# INFO:tensorflow:Looking for images in 'Apple___Cedar_apple_rust'
# INFO:tensorflow:Looking for images in 'Apple___healthy'
# INFO:tensorflow:Looking for images in 'Blueberry___healthy'
# INFO:tensorflow:Looking for images in 'Cherry_(including_sour)___Powdery_mildew'
# INFO:tensorflow:Looking for images in 'Cherry_(including_sour)___healthy'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___Common_rust_'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___Northern_Leaf_Blight'
# INFO:tensorflow:Looking for images in 'Corn_(maize)___healthy'
# INFO:tensorflow:Looking for images in 'Grape___Black_rot'
# INFO:tensorflow:Looking for images in 'Grape___Esca_(Black_Measles)'
# INFO:tensorflow:Looking for images in 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)'
# ...

# %%
#if stuck building toco https://github.com/bazelbuild/bazel/issues/5593
#toco --help
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-84ee5ffc5925> in <module>()
# ----> 1 toco --help
#
# NameError: name 'toco' is not defined

# %%
#--how_many_training_steps=500 \

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/flower_photos/daisy/21652746_cc379e0eea_m.jpg
# Out:
# Evaluation time (1-image): 1.626s
#
# daisy (score=1.00000)
# sunflowers (score=0.00000)
# dandelion (score=0.00000)
# corn maize healthy (score=0.00000)
# pepper bell bacterial spot (score=0.00000)

# %% [markdown]
# ##Expected result
# Evaluation time (1-image): 2.116s
# daisy (score=0.98734)
# sunflowers (score=0.01043)
# dandelion (score=0.00166)
# tulips (score=0.00053)
# roses (score=0.00004)

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/flower_photos/roses/2414954629_3708a1a04d.jpg
# Out:
# Evaluation time (1-image): 0.303s
#
# roses (score=1.00000)
# tulips (score=0.00000)
# corn maize healthy (score=0.00000)
# pepper bell bacterial spot (score=0.00000)
# peach healthy (score=0.00000)

# %% [markdown]
# ##Expected result
# Evaluation time (1-image): 0.650s
#
# roses (score=0.88883)
# tulips (score=0.09965)
# dandelion (score=0.00632)
# sunflowers (score=0.00420)
# daisy (score=0.00101)

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/test_photos/Grape___Black_rot/0b11ac6a-9e24-4d9c-bbe9-e180eb81ff38___FAM_B.Rot0581.JPG
# Out:
# Evaluation time (1-image): 0.289s
#
# grape black rot (score=1.00000)
# grape leaf blight isariopsis leaf spot (score=0.00000)
# tulips (score=0.00000)
# sunflowers (score=0.00000)
# pepper bell healthy (score=0.00000)

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/test_photos/Corn_(maize)___Common_rust_/RS_Rust2226.JPG
# Out:
# Evaluation time (1-image): 0.271s
#
# corn maize common rust (score=1.00000)
# corn maize cercospora leaf spot gray leaf spot (score=0.00000)
# tulips (score=0.00000)
# grape black rot (score=0.00000)
# pepper bell healthy (score=0.00000)

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/test_photos/Potato___Late_blight/1d4acd15-f2b9-4a2e-87da-9d5a2cc6a642___RS_LB2752.JPG
# Out:
# Evaluation time (1-image): 0.264s
#
# potato late blight (score=1.00000)
# potato early blight (score=0.00000)
# apple black rot (score=0.00000)
# apple cedar apple rust (score=0.00000)
# pepper bell healthy (score=0.00000)

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/test_photos/Tomato___healthy/0f9a114d-1df8-442c-90e7-d14d2f6efb23___RS_HL9964.JPG
# Out:
# Evaluation time (1-image): 0.266s
#
# tomato healthy (score=1.00000)
# tulips (score=0.00000)
# corn maize healthy (score=0.00000)
# pepper bell bacterial spot (score=0.00000)
# peach healthy (score=0.00000)

# %%
# %run scripts\label_image.py \
    --graph=tf_files/retrained_graph.pb  \
    --image=tf_files/test_photos/Tomato___Bacterial_spot/0740bf94-09c3-4718-8375-6ceed7db97a3___GCREC_Bact.Sp3628.JPG
# Out:
# Evaluation time (1-image): 0.269s
#
# tomato septoria leaf spot (score=1.00000)
# tomato bacterial spot (score=0.00000)
# tomato early blight (score=0.00000)
# corn maize healthy (score=0.00000)
# peach healthy (score=0.00000)

# %% [markdown]
# Evaluation time (1-image): 0.620s
#
# tomato septoria leaf spot (score=0.44783)
# tomato early blight (score=0.19113)
# tomato late blight (score=0.13779)
# tomato bacterial spot (score=0.07294)
# tomato leaf mold (score=0.07191)
